# %%
import torch
import torchvision
from torchvision import transforms
from PIL import Image, ImageDraw
from detect_object import Detect_object
import numpy as np

# %%
# %%time
img , res = Detect_object.process('1.jpg')
# Out:
# Wall time: 4.44 s

# %%
Detect_object.visualiza(img, res)
# Out:
# <PIL.Image.Image image mode=RGB size=650x1000 at 0x200BEB4C5F8>
